# %%
import json
import pprint

# %%
file = "output_relik-cie-small_meco.json"
with open(file, "r", encoding="utf-8") as f:
    data = json.load(f)

pp = pprint.PrettyPrinter(indent=2, width=120)
pp.pprint(data)
# Out:
# { 'candidates': { 'span': [ [ [ { 'id': 2330270,
#                                   'metadata': { 'definition': 'In ancient Roman religion and myth, Janus ( JAY nəs; '
#                                                               'Ianvs ) is the god of beginnings, gates, transitions, '
#                                                               'time, duality, doorways, passages, frames, and endings. '
#                                                               'He is usually depicted as having two faces. The month '
#                                                               'of January is named for Janus (Ianuarius). According to '
#                                                               "ancient Roman farmers' almanacs, Juno was mistaken as "
#                                                               'the tutelary deity of the month of January, but Juno is',
#                                                 'wikidata': 'Q167685'},
# ...

# %%
file_1 = "output_relik-cie-small_meco_threshold=0.1_window=128.json"
file_2 = "output_relik-cie-small_meco_threshold=0.1_window=256.json"
file_3 = "output_relik-cie-small_meco_threshold=0.1_window=sentence.json"
file_4 = "output_relik-cie-small_meco_threshold=0.1_window=None.json"
with open(file_4, "r", encoding="utf-8") as f:
    data = json.load(f)

pp = pprint.PrettyPrinter(indent=2, width=120)
pp.pprint(data)
